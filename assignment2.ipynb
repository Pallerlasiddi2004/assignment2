# %% [markdown]
# <a href="https://colab.research.google.com/github/Pallerlasiddi2004/assignment2/blob/main/assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Given,
#
# f(x,y)= 3x² + 5e^(-y) +10
#
# iteration 1:
#
# Let x=2, y=2, n=0.01
#
# gradient at x= 2 => d/dx(3x² + 5e^(-y)+10)
#
#                 =6(x)
#
#                 =6(2)
#
#               x = 12
#
# gradient at y= 1 => d/dy(3x² + 5e^(-y)+10)
#
#                 =-5(e^(-y))
#
#                 =-5(e^(-2))
#
#               y = -0.6766764162
#
# Now, Δx=-n*grad at x
#
#                 =-0.01*12
#
#              Δx = -0.12
#
#
# x1 = x+Δx
#
#                =12+(-0.12)
#
#             x1 = 11.88
#
# Δy=-n*grad at y
#
#               =-0.01*(-5(e^(-2))
#
#               =-0.01*-0.6766764162
#
#            Δy = 0.006766764162
#
# y1 = y+Δy
#
#           =-0.6766764162 + 0.006766764162
#
#       y1 = -0.669909652
#
# Now,
#
# iteration 2:
#
# x1=11.88, y1=-0.669909652, n=0.01
#
# gradient at x1=11.88 => d/dx(3x² + 5e^(-y)+10)
#
#             =6(x1)
#
#             =6(11.88)
#
#          x1 = 71.28
#
# gradient at y1=-0.669909652 => d/dx(3x² + 5e^(-y)+10)
#
#             =-5(e^(-y1))
#
#             =-5(e^(-0.669909652))
#
#          y1 = -2.558774059
#
# Δx1=-n*grad at x1
#
#             =-0.01*71.28
#
#          Δx1 =-0.7128
#
# x2=x1+Δx1
#
#             =71.28+(-0.7128)
#
#          x2 =70.5672
#
# Δy1=-n*grad ay y1
#
#             =-0.01*(-2.558774059)
#
#         Δy1 =0.02558774059
#
# y2=y1+Δy1
#
#            =(-2.558774059)+ 0.02558774059
#
#            =-2.533186318
#
#
# The value of iteration 1:
#
#       x1=11.88
#
#       y1=-0.669909652
#
# The value of iteration 2:
#
#       x2=70.5672
#
#       y2=-2.533186318
#
#
#     #This manual work is formatted as code

# %%
import numpy
x_o=2
y_o=2
eta=0.01
eps=0.000001
del_x=2
del_y=2
max_iters=10000
iters=0
def deriv(x,y):
  x_deriv=6*(x)
  y_deriv=-5*(numpy.exp(-y))
  return  x_deriv,y_deriv
while max(abs(del_x),abs(del_y)) > eps and iters < max_iters:
  prev_x=x_o
  prev_y=y_o
  del_x,del_y=deriv(prev_x,prev_y) 
  del_x=-eta*del_x
  del_y=-eta*del_y
  x_o=x_o+del_x
  y_o=y_o+del_y
  iters=iters+1
  print("iteration",iters,"\n x values is",x_o,"\n y value is",y_o)
print("local minimum occurs at",x_o,y_o)
# Out:
# Streaming output truncated to the last 5000 lines.
#  y value is 6.050182331378225
# iteration 8335
#  x values is 2.0974409805528746e-224
#  y value is 6.050300202984897
# iteration 8336
#  x values is 1.9715945217197021e-224
#  y value is 6.050418060698673
# iteration 8337
#  x values is 1.85329885041652e-224
#  y value is 6.050535904522826
# iteration 8338
#  x values is 1.7421009193915288e-224
#  y value is 6.0506537344606315
# iteration 8339
#  x values is 1.637574864228037e-224
#  y value is 6.05077155051536
# iteration 8340
#  x values is 1.539320372374355e-224
#  y value is 6.050889352690283
# iteration 8341
#  x values is 1.4469611500318937e-224
#  y value is 6.051007140988672
# iteration 8342
#  x values is 1.36014348102998e-224
#  y value is 6.051124915413794
# iteration 8343
#  x values is 1.2785348721681812e-224
#  y value is 6.051242675968918
# iteration 8344
#  x values is 1.2018227798380904e-224
#  y value is 6.051360422657311
# iteration 8345
# ...
