# %% [markdown]
# <a href="https://colab.research.google.com/github/Pallerlasiddi2004/assignment2/blob/main/assiginment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Given,
#
# f(x,y)= 3x² + 5e^(-y) +10
#
# iteration 1:
#
# Let x=2, y=2, n=0.01
#
# gradient at x= 2 => d/dx(3x² + 5e^(-y)+10)
#
#                 =6(x)
#
#                 =6(2)
#
#               x = 12
#
# gradient at y= 2 => d/dy(3x² + 5e^(-y)+10)
#
#                 =-5(e^(-y))
#
#                 =-5(e^(-2))
#
#               y = -0.6766764162
#
# Now, Δx=-n*grad at x
#
#                 =-0.01*12
#
#              Δx = -0.12
#
#
# x1 = x+Δx
#
#                = 2+(-0.12)
#
#             x1 = 1.88
#
# Δy=-n*grad at y
#
#               =-0.01*(-5(e^(-2))
#
#               =-0.01*-0.6766764162
#
#            Δy = 0.006766764162
#
# y1 = y+Δy
#
#           = 2 + 0.006766764162
#
#       y1 = 2.006766764
#
# Now,
#
# iteration 2:
#
# x1=1.88, y1=2.006766764, n=0.01
#
# gradient at x1=1.88 => d/dx(3x² + 5e^(-y)+10)
#
#             =6(x1)
#
#             =6(1.88)
#
#          x1 = 11.28
#
# gradient at y1=2.006766764 => d/dx(3x² + 5e^(-y)+10)
#
#             =-5(e^(-y1))
#
#             =-5(e^(2.006766764))
#
#          y1 = -37.19612825
#
# Now,
# Δx1=-n*grad at x1
#
#             =-0.01*11.28
#
#          Δx1 =-0.1128
#
# x2=x1+Δx1
#
#             =1.28+(-0.1128)
#
#          x2 =1.1672
#
# Δy1=-n*grad ay y1
#
#             =-0.01*(-37.19612825)
#
#         Δy1 =0.3719612825
#
# y2=y1+Δy1
#
#            =2.006766764 + 0.3719612825
#
#         y2 =2.378728047
#
#
# The value of iteration 1:
#
#       x1=1.88
#
#       y1=2.006766764
#
# The value of iteration 2:
#
#       x2=1.1671
#
#       y2=2.378728047
#
#
#
#     #This manual work is formatted as code

# %%
import numpy
x_o=2
y_o=2
eta=0.01
eps=0.000001
del_x=2
del_y=2
max_iters=2
iters=0
def deriv(x,y):
  x_deriv=6*(x)
  y_deriv=-5*(numpy.exp(-y))
  return  x_deriv,y_deriv
while max(abs(del_x),abs(del_y)) > eps and iters < max_iters:
  prev_x=x_o
  prev_y=y_o
  del_x,del_y=deriv(prev_x,prev_y) 
  del_x=-eta*del_x
  del_y=-eta*del_y
  x_o=x_o+del_x
  y_o=y_o+del_y
  iters=iters+1
  print("iteration",iters,"\n x values is",x_o,"\n y value is",y_o)
print("local minimum occurs at",x_o,y_o)
# Out:
# iteration 1
#  x values is 1.88
#  y value is 2.0067667641618305
# iteration 2
#  x values is 1.7671999999999999
#  y value is 2.0134878937996006
# local minimum occurs at 1.7671999999999999 2.0134878937996006
